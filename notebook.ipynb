# %%
import os
from dotenv import load_dotenv

# Load variables from .env into environment
load_dotenv()

# Read 


YOUTUBE_API_KEY = os.getenv("YOUTUBE_API_KEY")
PROXY_USERNAME = os.getenv("PROXY_USERNAME")
PROXY_PASSWORD = os.getenv("PROXY_PASSWORD")
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")


# # Example use
# print(f"API Key: {YOUTUBE_API_KEY}")
# print(f"Database: {PROXY_USERNAME}")
# print(f"Database: {PROXY_PASSWORD }")
# print(f"Database: {GEMINI_API_KEY }")

# %%
from youtube_transcript_api import YouTubeTranscriptApi
from youtube_transcript_api.proxies import WebshareProxyConfig
from youtube_transcript_api.formatters import JSONFormatter

ytt_api = YouTubeTranscriptApi(
    proxy_config=WebshareProxyConfig(
        proxy_username=PROXY_USERNAME,
        proxy_password=PROXY_PASSWORD
    )
)

# all requests done by ytt_api will now be proxied through Webshare
transcript=ytt_api.fetch("JP0sS7f0_oQ") # "JP0sS7f0_oQ" is the video-id here

formatter = JSONFormatter()

# format_transcript(transcript) turns the transcript into a JSON string.
json_formatted = formatter.format_transcript(transcript, indent=2)

# Now we can write it out to a file.
with open('your_filename.json', 'w', encoding='utf-8') as json_file:
    json_file.write(json_formatted)

# %%
# transcript
json_formatted
# Out:
# '[\n  {\n    "text": "remember",\n    "start": 1.68,\n    "duration": 2.78\n  },\n  {\n    "text": "hi everyone",\n    "start": 25.76,\n    "duration": 6.48\n  },\n  {\n    "text": "so now I will",\n    "start": 28.859,\n    "duration": 3.381\n  },\n  {\n    "text": "just made an announcement so you have",\n    "start": 33.84,\n    "duration": 4.46\n  },\n  {\n    "text": "the links",\n    "start": 35.94,\n    "duration": 6.18\n  },\n  {\n    "text": "and now I will open slider with",\n    "start": 38.3,\n    "duration": 6.06\n  },\n  {\n    "text": "questions",\n    "start": 42.12,\n    "duration": 2.24\n  },\n  {\n    "text": "so I noticed that last time I",\n    "start": 53.399,\n    "duration": 5.101\n  },\n  {\n    "text": "accidentally didn\'t cover some of the",\n    "start": 56.219,\n    "duration": 4.621\n  },\n  {\n    "text": "questions so maybe they came in last",\n    "start": 58.5,\n    "duration": 4.859\n  },\n  {\n    "text": "minute before I noticed them so that\'s",\n    "start": 60.84,\n    "duration": 4.92\n  },\n  {\n    "text": "why I kept the same slider link as",\n    "start": 63.359,\n    "duration": 6.541\n  },\n  {\n    "text": "previously so we\'ll just continue here",\n    "start": 65.76,\n    "duration": 5.76\n  },\n  {\n    "text": "um so how many people are already",\n    "start": 69.9,\n    "duration": 2.94\n  },\n  {\n    "text": "watching for people",\n    "start": 71.52,\n    "duration": 3.18\n  },\n  {\n    "text": "hey everyone",\n    "start": 72.84,\n    "duration": 5.819\n  },\n  {\n    "text": "so I will open it on my phone as well so",\n    "start": 74.7,\n    "duration": 7.82\n  },\n  {\n    "text": "I see what you\'re writing live chat",\n    "start": 78.659,\n    "duration": 3.861\n  },\n  {\n    "text": "hi everyone",\n    "start": 85.159,\n    "duration": 5.801\n  },\n  {\n    "text": "so how is it going with your project so",\n    "start": 88.02,\n    "duration": 4.22\n  },\n  {\n    "text": "far everyone",\n    "start": 90.96,\n    "duration": 4.56\n  },\n  {\n    "text": "selected the data set and started uh",\n    "start": 92.24,\n    "duration": 6.1\n  },\n  {\n    "text": "oh I don\'t know train the model and",\n    "start": 95.52,\n    "duration": 5.36\n  },\n  {\n    "text": "things like this",\n    "start": 98.34,\n    "duration": 2.54\n  },\n  {\n    "text": "foreign",\n    "start": 102.96,\n    "duration": 3.0\n  },\n  {\n    "text": "do I need to do anything else",\n    "start": 113.579,\n    "duration": 7.22\n  },\n  {\n    "text": "yeah I\'ll probably just share my screen",\n    "start": 116.34,\n    "duration": 4.459\n  },\n  {\n    "text": "and we will start covering questions",\n    "start": 121.799,\n    "duration": 3.981\n  },\n  {\n    "text": "okay I hope it\'s visible right",\n    "start": 125.939,\n    "duration": 4.281\n  },\n  {\n    "text": "so I think this question from Thomas",\n    "start": 130.86,\n    "duration": 5.099\n  },\n  {\n    "text": "from the previous uh",\n    "start": 133.2,\n    "duration": 5.1\n  },\n  {\n    "text": "from our previous office hours so Tom",\n    "start": 135.959,\n    "duration": 6.0\n  },\n  {\n    "text": "was also in Italy cool nah",\n    "start": 138.3,\n    "duration": 5.4\n  },\n  {\n    "text": "um could you please explain the topic of",\n    "start": 141.959,\n    "duration": 3.601\n  },\n  {\n    "text": "cohorts for our projects and I think",\n    "start": 143.7,\n    "duration": 4.8\n  },\n  {\n    "text": "this is um so this cohorts is confusing",\n    "start": 145.56,\n    "duration": 6.42\n  },\n  {\n    "text": "for many people so it\'s actually good to",\n    "start": 148.5,\n    "duration": 6.239\n  },\n  {\n    "text": "um to say it one more time so if I go to",\n    "start": 151.98,\n    "duration": 6.6\n  },\n  {\n    "text": "envelope zonkow and if I select uh",\n    "start": 154.739,\n    "duration": 6.72\n  },\n  {\n    "text": "if I select this project here you see",\n    "start": 158.58,\n    "d ...

# %%
import os
import json
from googleapiclient.discovery import build
from youtube_transcript_api import YouTubeTranscriptApi, NoTranscriptFound, TranscriptsDisabled
from youtube_transcript_api.proxies import WebshareProxyConfig # New import for proxy config
import re
import sys
import datetime # For formatting timestamps

# --- Configuration ---
# Directory to save the transcript JSON files
OUTPUT_DIR = "zoomcamp_transcripts"

# DataTalks.Club Zoomcamp Playlist URLs
ZOOMCAMP_PLAYLIST_URLS = [
 "https://www.youtube.com/playlist?list=PL3MmuxUbc_hIoBpuc900htYF4uhEAbaT-",  # LLM Zoomcamp 2025
    "https://www.youtube.com/playlist?list=PL3MmuxUbc_hKiIVNf7DeEt_tGjypOYtKV", # LLM Zoomcamp 2024
    "https://www.youtube.com/playlist?list=PL3MmuxUbc_hIB4fSqLy_0AfTjVLpgjV3R", #LLM zoomcamp
    "https://www.youtube.com/playlist?list=PL3MmuxUbc_hLDZ8j0yyeX14N7fGfV4ovC",  # MLOps Zoomcamp 2025
    "https://www.youtube.com/playlist?list=PL3MmuxUbc_hJD0AVR2Un_GSVGMpotGM2t", # MLOPS zoomcamp 2024
    "https://www.youtube.com/playlist?list=PL3MmuxUbc_hKqamJqQ7Ew8HxptJYnXqQM", # MLOps Zoomcamp 2023
    "http://www.youtube.com/playlist?list=PL3MmuxUbc_hLG1MoGNxJ9DmQSSM2bEdQT",  # MLOps Zoomcamp 2022
    "https://www.youtube.com/playlist?list=PL3MmuxUbc_hIUISrluw_A7wDSmfOhErJK", # MLOps Zoomcamp  
    "http://www.youtube.com/playlist?list=PL3MmuxUbc_hJZdpLpRHp7dg6EOx828q6y",  # Data Engineering Zoomcamp 2025
    "https://www.youtube.com/playlist?list=PL3MmuxUbc_hKihpnNQ9qtTmWYy26bPrSb", # Data Engineering Zoomcamp 2024
    "https://www.youtube.com/playlist?list=PL3MmuxUbc_hJjEePXIdE-LVUx_1ZZjYGW", # Data Engineering Zoomcamp 2023
    "https://www.youtube.com/playlist?list=PL3MmuxUbc_hKVX8VnwWCPaWlIHf1qmg8s", # Data Engineering Zoomcamp 2022
    "http://www.youtube.com/playlist?list=PL3MmuxUbc_hJed7dXYoJw8DoCuVHhGEQb" , # Data Engineering Zoomcamp 
    "https://www.youtube.com/playlist?list=PL3MmuxUbc_hJoui-E7wf2r5wWgET3MMZt",  # Machine Learning Zoomcamp 2024
    "https://www.youtube.com/playlist?list=PL3MmuxUbc_hJo_PzMibLDcEGyazxYAtV0", # Machine Learning Zoomcamp 2023
    "https://www.youtube.com/playlist?list=PL3MmuxUbc_hL5QBBEyKUXKuTNx-3cTpKs", # Machine Learning Zoomcamp 2022
    "https://www.youtube.com/playlist?list=PL3MmuxUbc_hL4Gx-wzOJMT4q1K-cArKqu", # Machine Learning Zoomcamp 2021
    "http://www.youtube.com/playlist?list=PL3MmuxUbc_hIhxl5Ji8t4O6lPAOpHaCLR"  # Machine Learning Zoomcamp
]

# --- YouTube Data API Configuration ---
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, developerKey=YOUTUBE_API_KEY)

# --- Proxy Configuration for youtube-transcript-api ---

# Initialize YouTubeTranscriptApi with proxy config
# This instance will be reused for all transcript fetches
ytt_api = YouTubeTranscriptApi(
    proxy_config=WebshareProxyConfig(
        proxy_username=PROXY_USERNAME,
        proxy_password=PROXY_PASSWORD
    )
)

# --- Helper Functions ---

def clean_filename(title):
    """Cleans a string to be suitable for a filename."""
    s = str(title).strip().replace(' ', '_')
    s = re.sub(r'(?u)[^-\w.]', '', s)
    return s

def format_timestamp(seconds):
    """Formats seconds into HH:MM:SS string."""
    return str(datetime.timedelta(seconds=int(seconds)))

# %%
import os
import json
from googleapiclient.discovery import build
from youtube_transcript_api import YouTubeTranscriptApi, NoTranscriptFound, TranscriptsDisabled
from youtube_transcript_api.proxies import WebshareProxyConfig # New import for proxy config
import re
import sys
import datetime # For formatting timestamps
def get_playlist_id_from_url(url):
    """Extracts playlist ID from a YouTube playlist URL."""
    match = re.search(r'list=([a-zA-Z0-9_-]+)', url)
    if match:
        return match.group(1)
    return None


get_playlist_id_from_url("http://www.youtube.com/playlist?list=PL3MmuxUbc_hIhxl5Ji8t4O6lPAOpHaCLR")
# Out:
# 'PL3MmuxUbc_hIhxl5Ji8t4O6lPAOpHaCLR'

# %%
def get_video_urls_from_playlist(playlist_url):
    """
    Retrieves all video URLs from a given YouTube playlist URL using YouTube Data API.
    """
    playlist_id = get_playlist_id_from_url(playlist_url)
    if not playlist_id:
        print(f"  Error: Could not extract playlist ID from URL: {playlist_url}. Skipping.")
        return []

    video_urls = []
    next_page_token = None

    print(f"  Fetching video URLs from playlist ID: '{playlist_id}' using YouTube Data API...")
    try:
        while True:
            playlist_items_request = youtube.playlistItems().list(
                part="snippet",
                playlistId=playlist_id,
                maxResults=50,
                pageToken=next_page_token
            )
            playlist_items_response = playlist_items_request.execute()

            for item in playlist_items_response.get("items", []):
                video_id = item["snippet"]["resourceId"]["videoId"]
                video_urls.append(f"https://www.youtube.com/watch?v={video_id}")
            
            next_page_token = playlist_items_response.get("nextPageToken")
            if not next_page_token:
                break

        print(f"  Successfully fetched {len(video_urls)} video URLs from playlist.")
        return video_urls

    except Exception as e:
        print(f"  Error fetching playlist {playlist_url} with YouTube Data API: {e}")
        print("  Please ensure your YOUTUBE_API_KEY is correct and YouTube Data API v3 is enabled for your project.")
        return []
get_video_urls_from_playlist("http://www.youtube.com/playlist?list=PL3MmuxUbc_hIhxl5Ji8t4O6lPAOpHaCLR")
# Out:
#   Fetching video URLs from playlist ID: 'PL3MmuxUbc_hIhxl5Ji8t4O6lPAOpHaCLR' using YouTube Data API...
#   Successfully fetched 107 video URLs from playlist.
# ['https://www.youtube.com/watch?v=8wuR_Oz-to0',
#  'https://www.youtube.com/watch?v=Crm_5n4mvmg',
#  'https://www.youtube.com/watch?v=CeukwyUdaz8',
#  'https://www.youtube.com/watch?v=j9kcEuGcC2Y',
#  'https://www.youtube.com/watch?v=dCa3JvmJbr0',
#  'https://www.youtube.com/watch?v=OH_R0Sl9neM',
#  'https://www.youtube.com/watch?v=pqQFlV3f9Bo',
#  'https://www.youtube.com/watch?v=Qa0-jYtRdbY',
#  'https://www.youtube.com/watch?v=zZyKUeOR4Gg',
#  'https://www.youtube.com/watch?v=0j3XK5PsnxA',
#  'https://www.youtube.com/watch?v=VRrEEVeJ440',
#  'https://www.youtube.com/watch?v=vM3SqPNlStE',
#  'https://www.youtube.com/watch?v=Kd74oR4QWGM',
#  'https://www.youtube.com/watch?v=k6k8sQ0GhPM',
#  'https://www.youtube.com/watch?v=ck0IfiPaQi0',
#  'https://www.youtube.com/watch?v=Dn1eTQLsOdA',
#  'https://www.youtube.com/watch?v=YkyevnYyAww',
#  'https://www.youtube.com/watch?v=hx6nak-Y11g',
#  'https://www.youtube.com/watch?v=SvPpMMYtYbU',
#  'https://www.youtube.com/watch?v=0LWoFtbzNUM',
#  'https://www.youtube.com/watch?v=rawGPXg2ofE',
#  'https://www.youtube.com/watch?v=-aEShw4ftB0',
#  'https://www.youtube.com/watch?v=sGLAToAAMa4',
#  'https://www.youtube.com/watch?v=91ve3EJlHBc',
#  'https://www.youtube.com/watch?v=lW-YVxPgzQw',
#  'https://www.youtube.com/watch?v=KT--uIJozes',
#  'https://www.youtube.com/watch?v=_qI01YXbyro',
#  'https://www.youtube.com/watch?v=0Zw04wdeTQo',
#  'https://www.youtube.com/watch?v=VSGGU9gYvdg',
#  'https://www.youtube.com/watch?v=_lwz34sOnSE',
#  'https://www.youtube.com/watch?v=BNF1wjBwTQA',
#  'https://www.youtube.com/watch?v=fzdzPLlvs40',
#  'https://www.youtube.com/watch?v=_u2YaGT6RN0',
#  'https://www.youtube.com/watch?v=mz1707QVxiY',
#  'https://www.youtube.com/watch?v=L-mjQFN5aR0',
#  'https://www.youtube.com/watch?v=7KFE2ltnBAg',
#  'https://www.youtube.com/watch?v=hae_jXe2fN0',
#  'https://www.youtube.com/watch?v=OUrlxnUAAEA',
#  'https://www.youtube.com/watch?v=Y-NGmnFpNuM',
#  'https://www.youtube.com/watch?v=Zz6oRGsJkW4',
#  'https://www.youtube.com/watch?v=gmg5jw1bM8A',
#  'https://www.youtube.com/watch?v=FW_l7lB0HUI',
#  'https://www.youtube.com/watch?v=Jt2dDLSlBng',
#  'https://www.youtube.com/watch?v=gRLP_mlglMM',
#  'https://www.youtube.com/watch?v=dnBZLk53sQI',
#  'https://www.youtube.com/watch?v=B5PATo1J6yw',
#  'https://www.youtube.com/watch?v=hvIQPAwkVZo',
#  'https://www.youtube.com/watch?v=BIIZaVtUbf4',
#  'https://www.youtube.com/watch?v=-v8XEQ2AHvQ',
#  'https://www.youtube.com/watch?v=agIFak9A3m8',
#  'https://www.youtube.com/watch?v=EJpqZ7OlwFU',
#  'https://www.youtube.com/watch?v=W7ubna1Rfv8',
#  'https://www.youtube.com/watch?v=Q7ZWPgPnRz8',
#  'https://www.youtube.com/watch?v=BMXh8JGROHM',
#  'https://www.youtube.com/watch?v=wAtyYZ6zvAs',
#  'https://www.youtube.com/watch?v=HGPJ4ekhcLg',
#  'https://www.youtube.com/watch?v=sSAqYSk7Br4',
#  'https://www.youtube.com/watch?v=GJGmlfZoCoU',
#  'https://www.youtube.com/watch?v=tfuQdI3YO2c',
#  'https://www.youtube.com/watch?v=YGiQvFbSIg8',
#  'https://www.youtube.com/watch?v=XODz6LwKY7g',
#  'https://www.youtube.com/watch?v=XJaxwH50Qok',
#  'https://www.youtube.com/watch?v=FZhcmOfNNZE',
#  'https://www.youtube.com/watch?v=xFarGClszEM',
#  'https://www.youtube.com/watch?v=VX6ftRzYROM',
#  'https://www.youtube.com/watch?v=lqdnyIVQq-M',
#  'https://www.youtube.com/watch?v=JZ6sRZ_5j_c',
#  'https://www.youtube.com/watch?v=it1Lu7NmMpw',
#  'https://www.youtube.com/watch?v=WZCjsyV8hZE',
#  'https://www.youtube.com/watch?v=R6o_CUmoN9Q',
#  'https://www.youtube.com/watch?v=qGDXEz-cr6M',
#  'https://www.youtube.com/watch?v=BN-fnYzbdc8',
#  'https://www.youtube.com/watch?v=WKHylqfNmq4',
#  'https://www.youtube.com/watch?v=2gPmRRGz0Hc',
#  'https://www.youtube.com/watch?v=NRpGUx0o3Ps',
#  'https://www.youtube.com/watch?v=bSRRrorvAZs',
#  'https://www.youtube.com/watch?v=74YmhVM6FTM',
#  'https://www.youtube.com/watch?v=aoPfVsS3BDE',
#  'https://www.youtube.com/watch?v=_QpDGJwFjYA',
#  'https://www.youtube.com/watch?v=cM1WHKae1wo',
#  'https://www.youtube.com/watch?v=mn0BcXJlRFM',
#  'https://www.youtube.com/watch?v=JLIVwIsU6RA',
#  'https://www.youtube.com/watch?v=_UX8-2WhHZo',
#  'https://www.youtube.com/watch?v=OzZA4mSBE0Q',
#  'https://www.youtube.com/watch?v=XXBUivsHhec',
#  'https://www.youtube.com/watch?v=y4_YQjfOsDo',
#  'https://www.youtube.com/watch?v=kBch5oD5BkY',
#  'https://www.youtube.com/watch?v=wyZ9aqQOXvs',
#  'https://www.youtube.com/watch?v=bu3nPiHCNLU',
#  'https://www.youtube.com/watch?v=7gI1UH31xb4',
#  'https://www.youtube.com/watch?v=4SXZfzNZ3IQ',
#  'https://www.youtube.com/watch?v=mvPER7YfTkw',
#  'https://www.youtube.com/watch?v=deXR2fThYDw',
#  'https://www.youtube.com/watch?v=OIlrS14Zi0o',
#  'https://www.youtube.com/watch?v=ZhQQfpWfkKY',
#  'https://www.youtube.com/watch?v=UjVkpszDzgk',
#  'https://www.youtube.com/watch?v=PPUCVRIV9t8',
#  'https://www.youtube.com/watch?v=6vHLMdnjO2w',
#  'https://www.youtube.com/watch?v=89jxeddZtC0',
#  'https://www.youtube.com/watch?v=J5LMRTIu4jY',
#  'https://www.youtube.com/watch?v=CFWK05dQoGM',
#  'https://www.youtube.com/watch?v=A3tFt14iTEI',
#  'https://www.youtube.com/watch?v=8kBIDggLwgE',
#  'https://www.youtube.com/watch?v=REGNWrHZiCw',
#  'https://www.youtube.com/watch?v=iXwQb2LRKGI',
#  'https://www.youtube.com/watch?v=haowRqeAqJU',
#  'https://www.youtube.com/watch?v=MpuTzBSYBBI']

# %%
def get_playlist_title_from_id(playlist_id):
    """Retrieves playlist title using YouTube Data API."""
    try:
        playlist_request = youtube.playlists().list(
            part="snippet",
            id=playlist_id
        )
        playlist_response = playlist_request.execute()
        if playlist_response.get("items"):
            return playlist_response["items"][0]["snippet"]["title"]
    except Exception as e:
        print(f"Error getting playlist title for ID {playlist_id}: {e}. Using default title.")
    return "Unknown Playlist"
get_playlist_title_from_id("PL3MmuxUbc_hIhxl5Ji8t4O6lPAOpHaCLR")
# Out:
# 'Machine Learning Zoomcamp'

# %%
import json

with open("zoomcamp_transcripts/all_zoomcamp_metadata_with_segmented_transcripts.json", "r") as f:
    transcript_data = json.load(f)

# %%
len(transcript_data)
# Out:
# 258849

# %%
len(transcript_data[0])
# Out:
# 9

# %%
transcript_data[0]
# Out:
# {'video_id': 'GH3lrOsU3AU',
#  'video_title': 'How to Build Agentic\u202fRAG Pipelines with OpenAI Function\u202fCalling? - LLM\u202fZoomcamp Bonus Module',
#  'video_url': 'https://www.youtube.com/watch?v=GH3lrOsU3AU',
#  'playlist_id': 'PL3MmuxUbc_hIoBpuc900htYF4uhEAbaT-',
#  'playlist_title': 'LLM Zoomcamp 2025',
#  'text': 'Hi everyone, welcome to our bonus module',
#  'start': 0.0,
#  'duration': 5.839,
#  'end': 5.839}

# %%
from collections import defaultdict

# Group segments by video
grouped_by_video = defaultdict(list)
for entry in transcript_data:
    grouped_by_video[entry["video_id"]].append(entry)

# %%
len(grouped_by_video[0])
# Out:
# 0

# %% [markdown]
# Step 1: Chunk Transcript by Time (~30 seconds)
# Here’s a custom implementation using Python with LangChain-style preprocessing, but it respects your start and end times:

# %%
import json

# Load your transcript JSON
with open("zoomcamp_transcripts/all_zoomcamp_metadata_with_segmented_transcripts.json", "r") as f:
    transcript = json.load(f)

# Step 1: Group transcript into ~30s chunks
def group_transcript_by_time(transcript, window=30):
    chunks = []
    current_chunk = None
    current_end = None

    for entry in transcript:
        start = entry.get("start")
        end = entry.get("end")

        # Skip bad entries
        if start is None or end is None:
            continue

        if current_chunk is None:
            current_chunk = {
                "video_id": entry["video_id"],
                "video_url": entry["video_url"],
                "start_time": start,
                "text": [entry["text"]],
            }
            current_end = end
            continue

        if start - current_chunk["start_time"] < window:
            current_chunk["text"].append(entry["text"])
            current_end = end
        else:
            # Finalize current chunk
            current_chunk["end_time"] = current_end
            current_chunk["text"] = " ".join(current_chunk["text"])
            chunks.append(current_chunk)

            # Start new chunk
            current_chunk = {
                "video_id": entry["video_id"],
                "video_url": entry["video_url"],
                "start_time": start,
                "text": [entry["text"]],
            }
            current_end = end

    # Final chunk
    if current_chunk:
        current_chunk["end_time"] = current_end
        current_chunk["text"] = " ".join(current_chunk["text"])
        chunks.append(current_chunk)

    return chunks

chunks = group_transcript_by_time(transcript, window=30)
print(f"✅ Chunks created: {len(chunks)}")
print("🧩 Example chunk:", chunks[0])
# Out:
# ✅ Chunks created: 197
# 🧩 Example chunk: {'video_id': 'GH3lrOsU3AU', 'video_url': 'https://www.youtube.com/watch?v=GH3lrOsU3AU', 'start_time': 0.0, 'text': 'Hi everyone, welcome to our bonus module of LLM Zoom camp. In this bonus module, we are going to talk about agents. When we launched our course this year a couple of uh weeks ago, I think it was one month one month one month ago, everyone everyone was asking like every second person in the Q&A section section was asking, "Hey, but what about agents? What about agents?" And uh the answer I gave back then was', 'end_time': 34.719}

# %%
import json
import pandas as pd
from collections import defaultdict

# Load your transcript JSON
with open("zoomcamp_transcripts/all_zoomcamp_metadata_with_segmented_transcripts.json", "r") as f:
    transcript = json.load(f)

# Step 1: Group transcript into ~30s chunks
def group_transcript_by_time(transcript_entries, window=30):
    chunks = []
    current_chunk = None
    current_end = None

    for entry in transcript_entries:
        start = entry.get("start")
        end = entry.get("end")

        if start is None or end is None:
            continue

        if current_chunk is None:
            current_chunk = {
                "video_id": entry["video_id"],
                "video_url": entry["video_url"],
                "start_time": start,
                "text": [entry["text"]],
            }
            current_end = end
            continue

        if start - current_chunk["start_time"] < window:
            current_chunk["text"].append(entry["text"])
            current_end = end
        else:
            current_chunk["end_time"] = current_end
            current_chunk["text"] = " ".join(current_chunk["text"])
            chunks.append(current_chunk)

            current_chunk = {
                "video_id": entry["video_id"],
                "video_url": entry["video_url"],
                "start_time": start,
                "text": [entry["text"]],
            }
            current_end = end

    if current_chunk:
        current_chunk["end_time"] = current_end
        current_chunk["text"] = " ".join(current_chunk["text"])
        chunks.append(current_chunk)

    return chunks

# Group transcript entries by video_id
transcript_by_video = defaultdict(list)
for entry in transcript:
    transcript_by_video[entry["video_id"]].append(entry)

summary_rows = []
all_chunks = []

for video_id, entries in transcript_by_video.items():
    entries_sorted = sorted(entries, key=lambda x: x["start"])
    num_transcript = len(entries_sorted)

    chunks = group_transcript_by_time(entries_sorted, window=30)
    num_chunks = len(chunks)

    print(f"[INFO] Processed video_id: {video_id}")
    print(f"       Transcript entries: {num_transcript}")
    print(f"       Chunks created:     {num_chunks}")

    if num_chunks == 0:
        print(f"  ⚠️  Warning: No chunks generated for video_id {video_id}")
    elif num_chunks < num_transcript / 10:
        print(f"  ⚠️  Warning: Chunk count much lower than transcript entries. Investigate {video_id}")

    all_chunks.extend(chunks)
    summary_rows.append({
        "video_id": video_id,
        "transcript_entries": num_transcript,
        "chunk_entries": num_chunks
    })

# Save summary table
df_summary = pd.DataFrame(summary_rows)
df_summary.to_csv("transcript_chunk_summary.csv", index=False)
print("\n✅ Summary table saved to 'transcript_chunk_summary.csv'")
# Out:
# [INFO] Processed video_id: GH3lrOsU3AU
#        Transcript entries: 2012
#        Chunks created:     179
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate GH3lrOsU3AU
# [INFO] Processed video_id: FgnelhEJFj0
#        Transcript entries: 1520
#        Chunks created:     132
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate FgnelhEJFj0
# [INFO] Processed video_id: 8lgiOLMMKcY
#        Transcript entries: 1245
#        Chunks created:     108
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 8lgiOLMMKcY
# [INFO] Processed video_id: YuxVHZ88hfg
#        Transcript entries: 1245
#        Chunks created:     113
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate YuxVHZ88hfg
# [INFO] Processed video_id: q-p36Ak6YI8
#        Transcript entries: 1832
#        Chunks created:     170
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate q-p36Ak6YI8
# [INFO] Processed video_id: nMrGK5QgPVE
#        Transcript entries: 2028
#        Chunks created:     195
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate nMrGK5QgPVE
# [INFO] Processed video_id: ifpqpB1ksGc
#        Transcript entries: 1683
#        Chunks created:     151
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate ifpqpB1ksGc
# [INFO] Processed video_id: q4Mb4SN-doo
#        Transcript entries: 1101
#        Chunks created:     100
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate q4Mb4SN-doo
# [INFO] Processed video_id: lre6h7vqz7A
#        Transcript entries: 992
#        Chunks created:     92
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate lre6h7vqz7A
# [INFO] Processed video_id: 8UIcSgyekvs
#        Transcript entries: 283
#        Chunks created:     26
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 8UIcSgyekvs
# [INFO] Processed video_id: pA9S1mTqAwU
#        Transcript entries: 745
#        Chunks created:     69
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate pA9S1mTqAwU
# [INFO] Processed video_id: ATchkIRsH4g
#        Transcript entries: 58
#        Chunks created:     6
# [INFO] Processed video_id: E0cAqBWfJYY
#        Transcript entries: 145
#        Chunks created:     16
# [INFO] Processed video_id: a86iTyxnFE4
#        Transcript entries: 285
#        Chunks created:     30
# [INFO] Processed video_id: 8KH6AS2PqWk
#        Transcript entries: 172
#        Chunks created:     18
# [INFO] Processed video_id: TdVEOzSoUCs
#        Transcript entries: 345
#        Chunks created:     39
# [INFO] Processed video_id: GzPV_HTmCkc
#        Transcript entries: 125
#        Chunks created:     13
# [INFO] Processed video_id: PVpBGs_iSjY
#        Transcript entries: 256
#        Chunks created:     26
# [INFO] Processed video_id: 4juoo_jk96U
#        Transcript entries: 165
#        Chunks created:     18
# [INFO] Processed video_id: R6L8PZ-7bGo
#        Transcript entries: 123
#        Chunks created:     14
# [INFO] Processed video_id: C5AWdL3kg1Q
#        Transcript entries: 247
#        Chunks created:     22
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate C5AWdL3kg1Q
# [INFO] Processed video_id: ptByfB_YcEg
#        Transcript entries: 563
#        Chunks created:     50
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate ptByfB_YcEg
# [INFO] Processed video_id: yb3nYGuIL4c
#        Transcript entries: 122
#        Chunks created:     11
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate yb3nYGuIL4c
# [INFO] Processed video_id: VRprIm9-VV8
#        Transcript entries: 666
#        Chunks created:     69
# [INFO] Processed video_id: OWqinqemCmk
#        Transcript entries: 373
#        Chunks created:     31
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate OWqinqemCmk
# [INFO] Processed video_id: XapKKBUMQ4M
#        Transcript entries: 752
#        Chunks created:     84
# [INFO] Processed video_id: BG8MlbidatA
#        Transcript entries: 213
#        Chunks created:     25
# [INFO] Processed video_id: BQN0TOi2Rew
#        Transcript entries: 639
#        Chunks created:     71
# [INFO] Processed video_id: qGFAX5ra1G8
#        Transcript entries: 120
#        Chunks created:     12
# [INFO] Processed video_id: 9BJppvgLINc
#        Transcript entries: 28
#        Chunks created:     3
# [INFO] Processed video_id: gP2ZOsG9Umg
#        Transcript entries: 48
#        Chunks created:     5
# [INFO] Processed video_id: H2oq5GSCKhM
#        Transcript entries: 34
#        Chunks created:     4
# [INFO] Processed video_id: z5NqDcaBglY
#        Transcript entries: 29
#        Chunks created:     4
# [INFO] Processed video_id: hrMrqRgZryg
#        Transcript entries: 25
#        Chunks created:     3
# [INFO] Processed video_id: cHrphSoRBX4
#        Transcript entries: 33
#        Chunks created:     4
# [INFO] Processed video_id: nuk7_soKMUA
#        Transcript entries: 36
#        Chunks created:     5
# [INFO] Processed video_id: Tq9Vbm_2z3o
#        Transcript entries: 256
#        Chunks created:     25
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate Tq9Vbm_2z3o
# [INFO] Processed video_id: TQ_ck6Q9gSQ
#        Transcript entries: 384
#        Chunks created:     47
# [INFO] Processed video_id: H4M55Ptc5cM
#        Transcript entries: 317
#        Chunks created:     35
# [INFO] Processed video_id: CRfg7tAsnUU
#        Transcript entries: 406
#        Chunks created:     52
# [INFO] Processed video_id: 8wrArv0DEKc
#        Transcript entries: 28
#        Chunks created:     4
# [INFO] Processed video_id: Q75JgLEXMsM
#        Transcript entries: 348
#        Chunks created:     33
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate Q75JgLEXMsM
# [INFO] Processed video_id: ozCpmkbJNJE
#        Transcript entries: 371
#        Chunks created:     36
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate ozCpmkbJNJE
# [INFO] Processed video_id: olvem333Bqo
#        Transcript entries: 294
#        Chunks created:     28
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate olvem333Bqo
# [INFO] Processed video_id: qz316T3U49Q
#        Transcript entries: 192
#        Chunks created:     20
# [INFO] Processed video_id: HObjFso2UJE
#        Transcript entries: 50
#        Chunks created:     5
# [INFO] Processed video_id: vkTiVwwch6A
#        Transcript entries: 158
#        Chunks created:     18
# [INFO] Processed video_id: 1lgbR5wMvsI
#        Transcript entries: 303
#        Chunks created:     30
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 1lgbR5wMvsI
# [INFO] Processed video_id: cX2vO1q2BGE
#        Transcript entries: 191
#        Chunks created:     17
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate cX2vO1q2BGE
# [INFO] Processed video_id: 4lX6sbdrs84
#        Transcript entries: 302
#        Chunks created:     26
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 4lX6sbdrs84
# [INFO] Processed video_id: TM5WxZ9EqoQ
#        Transcript entries: 159
#        Chunks created:     14
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate TM5WxZ9EqoQ
# [INFO] Processed video_id: VX-jMVN5ZQI
#        Transcript entries: 165
#        Chunks created:     15
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate VX-jMVN5ZQI
# [INFO] Processed video_id: ZV905K81sE4
#        Transcript entries: 284
#        Chunks created:     29
# [INFO] Processed video_id: ZdbIk8AltDU
#        Transcript entries: 590
#        Chunks created:     50
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate ZdbIk8AltDU
# [INFO] Processed video_id: qiWmCV0Knl0
#        Transcript entries: 104
#        Chunks created:     10
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate qiWmCV0Knl0
# [INFO] Processed video_id: APMrUnC_dy0
#        Transcript entries: 148
#        Chunks created:     14
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate APMrUnC_dy0
# [INFO] Processed video_id: bpxi6fKcyLw
#        Transcript entries: 531
#        Chunks created:     54
# [INFO] Processed video_id: fdIV4xCsp0c
#        Transcript entries: 471
#        Chunks created:     47
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate fdIV4xCsp0c
# [INFO] Processed video_id: yTKGSqkhgI4
#        Transcript entries: 194
#        Chunks created:     19
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate yTKGSqkhgI4
# [INFO] Processed video_id: yTO5sRw6x78
#        Transcript entries: 565
#        Chunks created:     57
# [INFO] Processed video_id: LlXclbD3pms
#        Transcript entries: 428
#        Chunks created:     46
# [INFO] Processed video_id: IB6jePK1s58
#        Transcript entries: 455
#        Chunks created:     46
# [INFO] Processed video_id: E9O0Tg68PPg
#        Transcript entries: 579
#        Chunks created:     66
# [INFO] Processed video_id: 6ulnHtJPCWY
#        Transcript entries: 819
#        Chunks created:     91
# [INFO] Processed video_id: lxpW2mR7dGk
#        Transcript entries: 381
#        Chunks created:     44
# [INFO] Processed video_id: vMHve2EyA5M
#        Transcript entries: 516
#        Chunks created:     61
# [INFO] Processed video_id: nQda9etJWW8
#        Transcript entries: 894
#        Chunks created:     109
# [INFO] Processed video_id: TW9M5VE8vpo
#        Transcript entries: 302
#        Chunks created:     28
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate TW9M5VE8vpo
# [INFO] Processed video_id: tyBRP_WewXA
#        Transcript entries: 403
#        Chunks created:     36
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate tyBRP_WewXA
# [INFO] Processed video_id: qqZU8nBtH90
#        Transcript entries: 1721
#        Chunks created:     147
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate qqZU8nBtH90
# [INFO] Processed video_id: rv43YJQsZIw
#        Transcript entries: 1493
#        Chunks created:     132
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate rv43YJQsZIw
# [INFO] Processed video_id: YmllO3ld5LE
#        Transcript entries: 1472
#        Chunks created:     131
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate YmllO3ld5LE
# [INFO] Processed video_id: 2jM7t-NTZxs
#        Transcript entries: 1326
#        Chunks created:     125
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 2jM7t-NTZxs
# [INFO] Processed video_id: 27GDodBA4ls
#        Transcript entries: 205
#        Chunks created:     20
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 27GDodBA4ls
# [INFO] Processed video_id: uAR4BhVCNbI
#        Transcript entries: 274
#        Chunks created:     25
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate uAR4BhVCNbI
# [INFO] Processed video_id: 6tvgEZsDmrw
#        Transcript entries: 166
#        Chunks created:     17
# [INFO] Processed video_id: 7hKrQmoARD8
#        Transcript entries: 19
#        Chunks created:     3
# [INFO] Processed video_id: 1lSOdTpoRug
#        Transcript entries: 24
#        Chunks created:     4
# [INFO] Processed video_id: FBh3P19lXj4
#        Transcript entries: 23
#        Chunks created:     3
# [INFO] Processed video_id: TcTMVn3BxeY
#        Transcript entries: 18
#        Chunks created:     3
# [INFO] Processed video_id: j0Hfaoc5wRY
#        Transcript entries: 12
#        Chunks created:     2
# [INFO] Processed video_id: z8erMV-6joY
#        Transcript entries: 6
#        Chunks created:     1
# [INFO] Processed video_id: qSzcfSHjJoY
#        Transcript entries: 10
#        Chunks created:     2
# [INFO] Processed video_id: tYPAl4Q8kpw
#        Transcript entries: 21
#        Chunks created:     3
# [INFO] Processed video_id: KP68DuJnk4Q
#        Transcript entries: 12
#        Chunks created:     2
# [INFO] Processed video_id: CbHaZcq_uGo
#        Transcript entries: 10
#        Chunks created:     2
# [INFO] Processed video_id: zsMHFq2C978
#        Transcript entries: 23
#        Chunks created:     3
# [INFO] Processed video_id: fZnxDhtPxYo
#        Transcript entries: 39
#        Chunks created:     5
# [INFO] Processed video_id: zfBB4KoZ7TM
#        Transcript entries: 33
#        Chunks created:     4
# [INFO] Processed video_id: P7PtegUFk3k
#        Transcript entries: 29
#        Chunks created:     3
# [INFO] Processed video_id: K_Z2Lm1Cyu4
#        Transcript entries: 118
#        Chunks created:     16
# [INFO] Processed video_id: Y2B-ivm7Mug
#        Transcript entries: 41
#        Chunks created:     5
# [INFO] Processed video_id: jwte-x3VwFE
#        Transcript entries: 36
#        Chunks created:     4
# [INFO] Processed video_id: Skr-WnxiQ8I
#        Transcript entries: 100
#        Chunks created:     13
# [INFO] Processed video_id: BvGZTl-UUQY
#        Transcript entries: 6
#        Chunks created:     1
# [INFO] Processed video_id: ScFZPSaOWK4
#        Transcript entries: 75
#        Chunks created:     10
# [INFO] Processed video_id: 6kqHoxAL0DY
#        Transcript entries: 43
#        Chunks created:     6
# [INFO] Processed video_id: GQMgCzI-Qrg
#        Transcript entries: 37
#        Chunks created:     5
# [INFO] Processed video_id: q4Quk6GeVRk
#        Transcript entries: 30
#        Chunks created:     5
# [INFO] Processed video_id: I5qR3OtASXs
#        Transcript entries: 16
#        Chunks created:     2
# [INFO] Processed video_id: DjtE3webtjE
#        Transcript entries: 27
#        Chunks created:     3
# [INFO] Processed video_id: H6D7zyqSQMw
#        Transcript entries: 19
#        Chunks created:     2
# [INFO] Processed video_id: ywzNac-OzFc
#        Transcript entries: 49
#        Chunks created:     6
# [INFO] Processed video_id: 6kcBWl3E8So
#        Transcript entries: 31
#        Chunks created:     4
# [INFO] Processed video_id: KZaS2oG9NDc
#        Transcript entries: 31
#        Chunks created:     4
# [INFO] Processed video_id: mytcFbH_ooY
#        Transcript entries: 20
#        Chunks created:     2
# [INFO] Processed video_id: JI0dhR7Bnhk
#        Transcript entries: 52
#        Chunks created:     6
# [INFO] Processed video_id: v2ls-gBBRac
#        Transcript entries: 33
#        Chunks created:     4
# [INFO] Processed video_id: J6ckSZczk8M
#        Transcript entries: 44
#        Chunks created:     5
# [INFO] Processed video_id: TgdFaf4mw38
#        Transcript entries: 25
#        Chunks created:     3
# [INFO] Processed video_id: w9zl3n2a3Wc
#        Transcript entries: 29
#        Chunks created:     3
# [INFO] Processed video_id: tPkA3WjLSHE
#        Transcript entries: 81
#        Chunks created:     10
# [INFO] Processed video_id: DMV2zEM50jY
#        Transcript entries: 8
#        Chunks created:     2
# [INFO] Processed video_id: o34Q_61iA4Y
#        Transcript entries: 734
#        Chunks created:     59
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate o34Q_61iA4Y
# [INFO] Processed video_id: hwtdTrBp6TA
#        Transcript entries: 1283
#        Chunks created:     102
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate hwtdTrBp6TA
# [INFO] Processed video_id: yNyqFMwEyL4
#        Transcript entries: 2155
#        Chunks created:     175
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate yNyqFMwEyL4
# [INFO] Processed video_id: 1-HdhcRP_7g
#        Transcript entries: 1039
#        Chunks created:     83
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 1-HdhcRP_7g
# [INFO] Processed video_id: Cqb7wyaNF08
#        Transcript entries: 161
#        Chunks created:     12
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate Cqb7wyaNF08
# [INFO] Processed video_id: rTUBTvXvXvM
#        Transcript entries: 335
#        Chunks created:     30
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate rTUBTvXvXvM
# [INFO] Processed video_id: x3bV8yMKjtc
#        Transcript entries: 395
#        Chunks created:     32
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate x3bV8yMKjtc
# [INFO] Processed video_id: 3YjagezFhOo
#        Transcript entries: 279
#        Chunks created:     23
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 3YjagezFhOo
# [INFO] Processed video_id: jVmaaqs63O8
#        Transcript entries: 693
#        Chunks created:     61
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate jVmaaqs63O8
# [INFO] Processed video_id: y89Ww85EUdo
#        Transcript entries: 425
#        Chunks created:     33
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate y89Ww85EUdo
# [INFO] Processed video_id: DmWgkNA6i-w
#        Transcript entries: 21
#        Chunks created:     2
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate DmWgkNA6i-w
# [INFO] Processed video_id: 2FUfbMqMEgg
#        Transcript entries: 64
#        Chunks created:     5
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 2FUfbMqMEgg
# [INFO] Processed video_id: NWeTQEGufiI
#        Transcript entries: 55
#        Chunks created:     5
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate NWeTQEGufiI
# [INFO] Processed video_id: fTQ3uqrGdrE
#        Transcript entries: 15
#        Chunks created:     2
# [INFO] Processed video_id: s4a-tU-t2XU
#        Transcript entries: 39
#        Chunks created:     3
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate s4a-tU-t2XU
# [INFO] Processed video_id: gdYM_-WShIU
#        Transcript entries: 73
#        Chunks created:     7
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate gdYM_-WShIU
# [INFO] Processed video_id: vp3VbmAIv_Y
#        Transcript entries: 57
#        Chunks created:     5
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate vp3VbmAIv_Y
# [INFO] Processed video_id: E42C1uyRiFA
#        Transcript entries: 39
#        Chunks created:     4
# [INFO] Processed video_id: K-FDw3HBcE4
#        Transcript entries: 45
#        Chunks created:     4
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate K-FDw3HBcE4
# [INFO] Processed video_id: 0WpR3ZUINpA
#        Transcript entries: 32
#        Chunks created:     3
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 0WpR3ZUINpA
# [INFO] Processed video_id: C5mM8Jkt2jI
#        Transcript entries: 53
#        Chunks created:     5
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate C5mM8Jkt2jI
# [INFO] Processed video_id: 3T5kUA3eWWc
#        Transcript entries: 1760
#        Chunks created:     126
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 3T5kUA3eWWc
# [INFO] Processed video_id: 8uJ36ZZr_Is
#        Transcript entries: 491
#        Chunks created:     34
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 8uJ36ZZr_Is
# [INFO] Processed video_id: feH1PMLyu-Q
#        Transcript entries: 431
#        Chunks created:     35
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate feH1PMLyu-Q
# [INFO] Processed video_id: _EeOs8joVt4
#        Transcript entries: 1730
#        Chunks created:     127
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate _EeOs8joVt4
# [INFO] Processed video_id: s2LcTqLEIxw
#        Transcript entries: 1002
#        Chunks created:     75
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate s2LcTqLEIxw
# [INFO] Processed video_id: 2J0YbHgSgYY
#        Transcript entries: 1659
#        Chunks created:     121
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 2J0YbHgSgYY
# [INFO] Processed video_id: DfmRb7J-Wuw
#        Transcript entries: 825
#        Chunks created:     59
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate DfmRb7J-Wuw
# [INFO] Processed video_id: Gzj2crFqgSI
#        Transcript entries: 398
#        Chunks created:     30
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate Gzj2crFqgSI
# [INFO] Processed video_id: mQVyA98dlak
#        Transcript entries: 731
#        Chunks created:     55
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate mQVyA98dlak
# [INFO] Processed video_id: koVhHl8BWFY
#        Transcript entries: 1
#        Chunks created:     0
#   ⚠️  Warning: No chunks generated for video_id koVhHl8BWFY
# [INFO] Processed video_id: uwGg6PE8sLg
#        Transcript entries: 1011
#        Chunks created:     92
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate uwGg6PE8sLg
# [INFO] Processed video_id: YhiTbZWFTzg
#        Transcript entries: 1484
#        Chunks created:     109
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate YhiTbZWFTzg
# [INFO] Processed video_id: WTJ5JYHIbeg
#        Transcript entries: 987
#        Chunks created:     92
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate WTJ5JYHIbeg
# [INFO] Processed video_id: JP0sS7f0_oQ
#        Transcript entries: 725
#        Chunks created:     60
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate JP0sS7f0_oQ
# [INFO] Processed video_id: hkbCP9aec4U
#        Transcript entries: 801
#        Chunks created:     67
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate hkbCP9aec4U
# [INFO] Processed video_id: eKzCjNXoCTc
#        Transcript entries: 253
#        Chunks created:     18
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate eKzCjNXoCTc
# [INFO] Processed video_id: Yb6NJwI7bXw
#        Transcript entries: 650
#        Chunks created:     52
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate Yb6NJwI7bXw
# [INFO] Processed video_id: MCFpURG506w
#        Transcript entries: 671
#        Chunks created:     50
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate MCFpURG506w
# [INFO] Processed video_id: ComkSIAB0k4
#        Transcript entries: 322
#        Chunks created:     26
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate ComkSIAB0k4
# [INFO] Processed video_id: xw9JfaWPPps
#        Transcript entries: 445
#        Chunks created:     32
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate xw9JfaWPPps
# [INFO] Processed video_id: oDSf0ThKsso
#        Transcript entries: 228
#        Chunks created:     17
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate oDSf0ThKsso
# [INFO] Processed video_id: gMiT11Bp05A
#        Transcript entries: 991
#        Chunks created:     74
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate gMiT11Bp05A
# [INFO] Processed video_id: VkkpVXW53bo
#        Transcript entries: 335
#        Chunks created:     26
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate VkkpVXW53bo
# [INFO] Processed video_id: umQ3Mo5G1o8
#        Transcript entries: 408
#        Chunks created:     33
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate umQ3Mo5G1o8
# [INFO] Processed video_id: r_m4VFEJ8yY
#        Transcript entries: 1
#        Chunks created:     0
#   ⚠️  Warning: No chunks generated for video_id r_m4VFEJ8yY
# [INFO] Processed video_id: KefdYuue_FE
#        Transcript entries: 457
#        Chunks created:     37
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate KefdYuue_FE
# [INFO] Processed video_id: ekT_JW213Tc
#        Transcript entries: 751
#        Chunks created:     57
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate ekT_JW213Tc
# [INFO] Processed video_id: s0uaFZSzwfI
#        Transcript entries: 95
#        Chunks created:     7
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate s0uaFZSzwfI
# [INFO] Processed video_id: MzcmWXYxi2s
#        Transcript entries: 314
#        Chunks created:     30
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate MzcmWXYxi2s
# [INFO] Processed video_id: IXSiYkP23zo
#        Transcript entries: 392
#        Chunks created:     31
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate IXSiYkP23zo
# [INFO] Processed video_id: r94QjpX9vSE
#        Transcript entries: 86
#        Chunks created:     7
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate r94QjpX9vSE
# [INFO] Processed video_id: iRunifGSHFc
#        Transcript entries: 991
#        Chunks created:     79
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate iRunifGSHFc
# [INFO] Processed video_id: teP9KWkP6SM
#        Transcript entries: 380
#        Chunks created:     27
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate teP9KWkP6SM
# [INFO] Processed video_id: XwTH8BDGzYk
#        Transcript entries: 381
#        Chunks created:     28
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate XwTH8BDGzYk
# [INFO] Processed video_id: MiA7LQin9c8
#        Transcript entries: 365
#        Chunks created:     28
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate MiA7LQin9c8
# [INFO] Processed video_id: cESCQE9J3ZE
#        Transcript entries: 287
#        Chunks created:     23
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate cESCQE9J3ZE
# [INFO] Processed video_id: iaJz-T7VWec
#        Transcript entries: 580
#        Chunks created:     47
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate iaJz-T7VWec
# [INFO] Processed video_id: OVUPIX88q88
#        Transcript entries: 386
#        Chunks created:     32
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate OVUPIX88q88
# [INFO] Processed video_id: TKHU7HAvGH8
#        Transcript entries: 849
#        Chunks created:     68
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate TKHU7HAvGH8
# [INFO] Processed video_id: 1ykg4YmbFVA
#        Transcript entries: 1031
#        Chunks created:     82
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 1ykg4YmbFVA
# [INFO] Processed video_id: Lugy1JPsBRY
#        Transcript entries: 297
#        Chunks created:     23
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate Lugy1JPsBRY
# [INFO] Processed video_id: 3_Uu0rInxWI
#        Transcript entries: 530
#        Chunks created:     54
# [INFO] Processed video_id: JMGe4yIoBRA
#        Transcript entries: 361
#        Chunks created:     26
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate JMGe4yIoBRA
# [INFO] Processed video_id: D7wfMAdgdF8
#        Transcript entries: 747
#        Chunks created:     56
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate D7wfMAdgdF8
# [INFO] Processed video_id: aewOpHSCkqI
#        Transcript entries: 492
#        Chunks created:     37
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate aewOpHSCkqI
# [INFO] Processed video_id: TCqr9HNcrsI
#        Transcript entries: 1669
#        Chunks created:     128
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate TCqr9HNcrsI
# [INFO] Processed video_id: 18Lbaaeigek
#        Transcript entries: 664
#        Chunks created:     50
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 18Lbaaeigek
# [INFO] Processed video_id: SQ0jBwd_3kk
#        Transcript entries: 322
#        Chunks created:     24
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate SQ0jBwd_3kk
# [INFO] Processed video_id: yixA3C1xSxc
#        Transcript entries: 209
#        Chunks created:     18
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate yixA3C1xSxc
# [INFO] Processed video_id: IjNrkqMYQeQ
#        Transcript entries: 380
#        Chunks created:     38
# [INFO] Processed video_id: kP3lzh_HfWY
#        Transcript entries: 238
#        Chunks created:     21
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate kP3lzh_HfWY
# [INFO] Processed video_id: zjvYhDPzFlY
#        Transcript entries: 280
#        Chunks created:     28
# [INFO] Processed video_id: s3G4PMsOMOA
#        Transcript entries: 280
#        Chunks created:     27
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate s3G4PMsOMOA
# [INFO] Processed video_id: fytrmPbcLhI
#        Transcript entries: 258
#        Chunks created:     26
# [INFO] Processed video_id: -c4iumyZMyw
#        Transcript entries: 100
#        Chunks created:     9
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate -c4iumyZMyw
# [INFO] Processed video_id: sNSk3ojISh8
#        Transcript entries: 1
#        Chunks created:     0
#   ⚠️  Warning: No chunks generated for video_id sNSk3ojISh8
# [INFO] Processed video_id: CJp1eFQP5nk
#        Transcript entries: 798
#        Chunks created:     61
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate CJp1eFQP5nk
# [INFO] Processed video_id: lBX0Gl7Z1ck
#        Transcript entries: 857
#        Chunks created:     65
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate lBX0Gl7Z1ck
# [INFO] Processed video_id: 9yMO86SYvuI
#        Transcript entries: 457
#        Chunks created:     35
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 9yMO86SYvuI
# [INFO] Processed video_id: uImvWE-iSDQ
#        Transcript entries: 822
#        Chunks created:     62
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate uImvWE-iSDQ
# [INFO] Processed video_id: lmMZ7Axk2T8
#        Transcript entries: 459
#        Chunks created:     35
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate lmMZ7Axk2T8
# [INFO] Processed video_id: F6DZdvbRZQQ
#        Transcript entries: 401
#        Chunks created:     30
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate F6DZdvbRZQQ
# [INFO] Processed video_id: zRcLgT7Qnio
#        Transcript entries: 172
#        Chunks created:     14
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate zRcLgT7Qnio
# [INFO] Processed video_id: -6scXrFcPNk
#        Transcript entries: 762
#        Chunks created:     66
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate -6scXrFcPNk
# [INFO] Processed video_id: JVydd1K6R7M
#        Transcript entries: 1481
#        Chunks created:     135
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate JVydd1K6R7M
# [INFO] Processed video_id: YWao0rnqVoI
#        Transcript entries: 262
#        Chunks created:     22
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate YWao0rnqVoI
# [INFO] Processed video_id: OMwwZ0Z_cdk
#        Transcript entries: 95
#        Chunks created:     8
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate OMwwZ0Z_cdk
# [INFO] Processed video_id: xkTWF9c33mU
#        Transcript entries: 409
#        Chunks created:     44
# [INFO] Processed video_id: jCNxqXCKh2s
#        Transcript entries: 358
#        Chunks created:     41
# [INFO] Processed video_id: X8cEEwi8DTM
#        Transcript entries: 1787
#        Chunks created:     151
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate X8cEEwi8DTM
# [INFO] Processed video_id: DPnAOu2csYA
#        Transcript entries: 1587
#        Chunks created:     136
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate DPnAOu2csYA
# [INFO] Processed video_id: aBQulSpOgfY
#        Transcript entries: 1657
#        Chunks created:     122
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate aBQulSpOgfY
# [INFO] Processed video_id: pgJWP_xqO1g
#        Transcript entries: 1919
#        Chunks created:     174
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate pgJWP_xqO1g
# [INFO] Processed video_id: P2loELMUUeI
#        Transcript entries: 2283
#        Chunks created:     191
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate P2loELMUUeI
# [INFO] Processed video_id: wpLmImIUlPg
#        Transcript entries: 342
#        Chunks created:     34
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate wpLmImIUlPg
# [INFO] Processed video_id: 91b8u9GmqB4
#        Transcript entries: 1174
#        Chunks created:     106
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 91b8u9GmqB4
# [INFO] Processed video_id: XOSUt8Ih3zA
#        Transcript entries: 228
#        Chunks created:     27
# [INFO] Processed video_id: AtRhA-NfS24
#        Transcript entries: 1710
#        Chunks created:     157
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate AtRhA-NfS24
# [INFO] Processed video_id: oLXhBM7nf2Q
#        Transcript entries: 1808
#        Chunks created:     153
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate oLXhBM7nf2Q
# [INFO] Processed video_id: 7PBvH6dHVxc
#        Transcript entries: 1421
#        Chunks created:     109
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 7PBvH6dHVxc
# [INFO] Processed video_id: L2BHFnZ6XjE
#        Transcript entries: 2008
#        Chunks created:     172
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate L2BHFnZ6XjE
# [INFO] Processed video_id: Li8-MWHhTbo
#        Transcript entries: 326
#        Chunks created:     23
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate Li8-MWHhTbo
# [INFO] Processed video_id: AicKRcK3pa4
#        Transcript entries: 241
#        Chunks created:     18
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate AicKRcK3pa4
# [INFO] Processed video_id: 2SV-av3L3-k
#        Transcript entries: 147
#        Chunks created:     11
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 2SV-av3L3-k
# [INFO] Processed video_id: stI-gg4QBnI
#        Transcript entries: 90
#        Chunks created:     7
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate stI-gg4QBnI
# [INFO] Processed video_id: pmhI-ezd3BE
#        Transcript entries: 170
#        Chunks created:     13
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate pmhI-ezd3BE
# [INFO] Processed video_id: Maidfe7oKLs
#        Transcript entries: 294
#        Chunks created:     26
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate Maidfe7oKLs
# [INFO] Processed video_id: 00LP360iYvE
#        Transcript entries: 202
#        Chunks created:     16
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 00LP360iYvE
# [INFO] Processed video_id: w0XmcASRUnc
#        Transcript entries: 319
#        Chunks created:     28
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate w0XmcASRUnc
# [INFO] Processed video_id: JKp_uzM-XsM
#        Transcript entries: 198
#        Chunks created:     16
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate JKp_uzM-XsM
# [INFO] Processed video_id: H0hWjWxB-rg
#        Transcript entries: 229
#        Chunks created:     19
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate H0hWjWxB-rg
# [INFO] Processed video_id: ZoeC6Ag5gQc
#        Transcript entries: 83
#        Chunks created:     7
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate ZoeC6Ag5gQc
# [INFO] Processed video_id: zAwAX5sxqsg
#        Transcript entries: 94
#        Chunks created:     7
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate zAwAX5sxqsg
# [INFO] Processed video_id: O_H7DCmq2rA
#        Transcript entries: 66
#        Chunks created:     6
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate O_H7DCmq2rA
# [INFO] Processed video_id: 9A872B5hb_0
#        Transcript entries: 55
#        Chunks created:     4
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 9A872B5hb_0
# [INFO] Processed video_id: 0YExsb2HgLI
#        Transcript entries: 158
#        Chunks created:     13
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 0YExsb2HgLI
# [INFO] Processed video_id: uUtj7N0TleQ
#        Transcript entries: 169
#        Chunks created:     12
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate uUtj7N0TleQ
# [INFO] Processed video_id: -zpVha7bw5A
#        Transcript entries: 1730
#        Chunks created:     142
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate -zpVha7bw5A
# [INFO] Processed video_id: RVTryVvSyw4
#        Transcript entries: 1229
#        Chunks created:     96
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate RVTryVvSyw4
# [INFO] Processed video_id: KIh_9tZiroA
#        Transcript entries: 184
#        Chunks created:     20
# [INFO] Processed video_id: xFAnfvhO3Ug
#        Transcript entries: 388
#        Chunks created:     32
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate xFAnfvhO3Ug
# [INFO] Processed video_id: a_nmLHb8hzw
#        Transcript entries: 1585
#        Chunks created:     121
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate a_nmLHb8hzw
# [INFO] Processed video_id: L04lvYqNlc0
#        Transcript entries: 401
#        Chunks created:     31
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate L04lvYqNlc0
# [INFO] Processed video_id: PK8yyMY54Vk
#        Transcript entries: 495
#        Chunks created:     37
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate PK8yyMY54Vk
# [INFO] Processed video_id: j8r2OigKBWE
#        Transcript entries: 1
#        Chunks created:     0
#   ⚠️  Warning: No chunks generated for video_id j8r2OigKBWE
# [INFO] Processed video_id: QXfmtJp3bXE
#        Transcript entries: 465
#        Chunks created:     37
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate QXfmtJp3bXE
# [INFO] Processed video_id: O-tyUOQccSs
#        Transcript entries: 2271
#        Chunks created:     169
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate O-tyUOQccSs
# [INFO] Processed video_id: ODYg_r72qaE
#        Transcript entries: 192
#        Chunks created:     16
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate ODYg_r72qaE
# [INFO] Processed video_id: I_K0lNu9WQw
#        Transcript entries: 271
#        Chunks created:     21
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate I_K0lNu9WQw
# [INFO] Processed video_id: 5_69yL2PPYI
#        Transcript entries: 318
#        Chunks created:     26
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 5_69yL2PPYI
# [INFO] Processed video_id: inNrUys7W8U
#        Transcript entries: 60
#        Chunks created:     6
# [INFO] Processed video_id: W3Zm6rjOq70
#        Transcript entries: 148
#        Chunks created:     13
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate W3Zm6rjOq70
# [INFO] Processed video_id: 8oLs6pzHp68
#        Transcript entries: 150
#        Chunks created:     12
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 8oLs6pzHp68
# [INFO] Processed video_id: cdtN6dhp708
#        Transcript entries: 788
#        Chunks created:     67
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate cdtN6dhp708
# [INFO] Processed video_id: W-rMz_2GwqQ
#        Transcript entries: 735
#        Chunks created:     66
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate W-rMz_2GwqQ
# [INFO] Processed video_id: Cx5jt-V5sgE
#        Transcript entries: 445
#        Chunks created:     41
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate Cx5jt-V5sgE
# [INFO] Processed video_id: QrDxPjX10iw
#        Transcript entries: 400
#        Chunks created:     34
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate QrDxPjX10iw
# [INFO] Processed video_id: psNSzqTsi-s
#        Transcript entries: 602
#        Chunks created:     47
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate psNSzqTsi-s
# [INFO] Processed video_id: gGC23ZK7lr8
#        Transcript entries: 78
#        Chunks created:     6
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate gGC23ZK7lr8
# [INFO] Processed video_id: Y76Ez_fIvtk
#        Transcript entries: 853
#        Chunks created:     81
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate Y76Ez_fIvtk
# [INFO] Processed video_id: 5hRJ8-6Fpyk
#        Transcript entries: 640
#        Chunks created:     66
# [INFO] Processed video_id: bkJZDmreIpA
#        Transcript entries: 1
#        Chunks created:     0
#   ⚠️  Warning: No chunks generated for video_id bkJZDmreIpA
# [INFO] Processed video_id: HxHqH2ARfxM
#        Transcript entries: 220
#        Chunks created:     17
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate HxHqH2ARfxM
# [INFO] Processed video_id: Vpt1BRWT1c0
#        Transcript entries: 1664
#        Chunks created:     121
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate Vpt1BRWT1c0
# [INFO] Processed video_id: 0yK7LXwYeD0
#        Transcript entries: 347
#        Chunks created:     27
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 0yK7LXwYeD0
# [INFO] Processed video_id: lqDMzReAtrw
#        Transcript entries: 407
#        Chunks created:     33
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate lqDMzReAtrw
# [INFO] Processed video_id: 9ksX9REfL8w
#        Transcript entries: 516
#        Chunks created:     43
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 9ksX9REfL8w
# [INFO] Processed video_id: s2U8MWJH5xA
#        Transcript entries: 1911
#        Chunks created:     150
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate s2U8MWJH5xA
# [INFO] Processed video_id: A1p5LQ0zzaQ
#        Transcript entries: 293
#        Chunks created:     25
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate A1p5LQ0zzaQ
# [INFO] Processed video_id: rFOFTfD1uGk
#        Transcript entries: 206
#        Chunks created:     16
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate rFOFTfD1uGk
# [INFO] Processed video_id: VhmmbqpIzeI
#        Transcript entries: 167
#        Chunks created:     15
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate VhmmbqpIzeI
# [INFO] Processed video_id: -0xl4GtSugQ
#        Transcript entries: 1111
#        Chunks created:     92
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate -0xl4GtSugQ
# [INFO] Processed video_id: yZ-d7nItpB8
#        Transcript entries: 1578
#        Chunks created:     119
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate yZ-d7nItpB8
# [INFO] Processed video_id: YtRtR2iTWR4
#        Transcript entries: 291
#        Chunks created:     23
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate YtRtR2iTWR4
# [INFO] Processed video_id: U7iBBV8Dn74
#        Transcript entries: 1720
#        Chunks created:     123
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate U7iBBV8Dn74
# [INFO] Processed video_id: Lh93tkpgEg0
#        Transcript entries: 1643
#        Chunks created:     120
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate Lh93tkpgEg0
# [INFO] Processed video_id: 3LK0elHi3fA
#        Transcript entries: 715
#        Chunks created:     59
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 3LK0elHi3fA
# [INFO] Processed video_id: TMEtKHw60dU
#        Transcript entries: 1648
#        Chunks created:     120
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate TMEtKHw60dU
# [INFO] Processed video_id: AcKecyC-ezM
#        Transcript entries: 1659
#        Chunks created:     119
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate AcKecyC-ezM
# [INFO] Processed video_id: QxqRUQMguyc
#        Transcript entries: 1668
#        Chunks created:     123
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate QxqRUQMguyc
# [INFO] Processed video_id: YKnnD8kKFUQ
#        Transcript entries: 1529
#        Chunks created:     116
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate YKnnD8kKFUQ
# [INFO] Processed video_id: Ma_Iirino88
#        Transcript entries: 1030
#        Chunks created:     78
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate Ma_Iirino88
# [INFO] Processed video_id: MPDHAKGPY2o
#        Transcript entries: 1390
#        Chunks created:     106
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate MPDHAKGPY2o
# [INFO] Processed video_id: vzoYhI8KTlY
#        Transcript entries: 513
#        Chunks created:     45
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate vzoYhI8KTlY
# [INFO] Processed video_id: OkUMcyQzypg
#        Transcript entries: 488
#        Chunks created:     50
# [INFO] Processed video_id: D9cQOefe5zA
#        Transcript entries: 492
#        Chunks created:     40
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate D9cQOefe5zA
# [INFO] Processed video_id: Xvk7eXOb9LQ
#        Transcript entries: 325
#        Chunks created:     28
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate Xvk7eXOb9LQ
# [INFO] Processed video_id: lAxAhHNeGww
#        Transcript entries: 1142
#        Chunks created:     102
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate lAxAhHNeGww
# [INFO] Processed video_id: UishFmq1hLM
#        Transcript entries: 340
#        Chunks created:     27
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate UishFmq1hLM
# [INFO] Processed video_id: UVI30Vxzd6c
#        Transcript entries: 1064
#        Chunks created:     85
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate UVI30Vxzd6c
# [INFO] Processed video_id: 4eCouvVOJUw
#        Transcript entries: 123
#        Chunks created:     10
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 4eCouvVOJUw
# [INFO] Processed video_id: iMxh6s_wL4Q
#        Transcript entries: 141
#        Chunks created:     11
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate iMxh6s_wL4Q
# [INFO] Processed video_id: rjf6yZNGX8I
#        Transcript entries: 341
#        Chunks created:     27
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate rjf6yZNGX8I
# [INFO] Processed video_id: T0KR4zcNXIY
#        Transcript entries: 110
#        Chunks created:     8
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate T0KR4zcNXIY
# [INFO] Processed video_id: 18jIzE41fJ4
#        Transcript entries: 75
#        Chunks created:     6
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 18jIzE41fJ4
# [INFO] Processed video_id: EYNwNlOrpr0
#        Transcript entries: 612
#        Chunks created:     46
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate EYNwNlOrpr0
# [INFO] Processed video_id: 2JM-ziJt0WI
#        Transcript entries: 722
#        Chunks created:     56
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 2JM-ziJt0WI
# [INFO] Processed video_id: 3IkfkTwqHx4
#        Transcript entries: 194
#        Chunks created:     15
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 3IkfkTwqHx4
# [INFO] Processed video_id: hCAIVe9N0ow
#        Transcript entries: 265
#        Chunks created:     21
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate hCAIVe9N0ow
# [INFO] Processed video_id: B1WwATwf-vY
#        Transcript entries: 443
#        Chunks created:     35
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate B1WwATwf-vY
# [INFO] Processed video_id: hKI6PkPhpa0
#        Transcript entries: 223
#        Chunks created:     18
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate hKI6PkPhpa0
# [INFO] Processed video_id: QEcps_iskgg
#        Transcript entries: 389
#        Chunks created:     31
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate QEcps_iskgg
# [INFO] Processed video_id: s2bOYDCKl_M
#        Transcript entries: 208
#        Chunks created:     20
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate s2bOYDCKl_M
# [INFO] Processed video_id: Y2ux7gq3Z0o
#        Transcript entries: 540
#        Chunks created:     55
# [INFO] Processed video_id: PBi0hHjLftk
#        Transcript entries: 397
#        Chunks created:     46
# [INFO] Processed video_id: ae-CV2KfoN0
#        Transcript entries: 1164
#        Chunks created:     96
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate ae-CV2KfoN0
# ...
#        Chunks created:     15
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 0LWoFtbzNUM
# [INFO] Processed video_id: rawGPXg2ofE
#        Transcript entries: 118
#        Chunks created:     9
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate rawGPXg2ofE
# [INFO] Processed video_id: -aEShw4ftB0
#        Transcript entries: 143
#        Chunks created:     11
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate -aEShw4ftB0
# [INFO] Processed video_id: sGLAToAAMa4
#        Transcript entries: 408
#        Chunks created:     31
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate sGLAToAAMa4
# [INFO] Processed video_id: 91ve3EJlHBc
#        Transcript entries: 321
#        Chunks created:     24
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 91ve3EJlHBc
# [INFO] Processed video_id: lW-YVxPgzQw
#        Transcript entries: 88
#        Chunks created:     7
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate lW-YVxPgzQw
# [INFO] Processed video_id: KT--uIJozes
#        Transcript entries: 256
#        Chunks created:     20
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate KT--uIJozes
# [INFO] Processed video_id: _qI01YXbyro
#        Transcript entries: 201
#        Chunks created:     15
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate _qI01YXbyro
# [INFO] Processed video_id: 0Zw04wdeTQo
#        Transcript entries: 250
#        Chunks created:     19
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 0Zw04wdeTQo
# [INFO] Processed video_id: VSGGU9gYvdg
#        Transcript entries: 238
#        Chunks created:     18
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate VSGGU9gYvdg
# [INFO] Processed video_id: _lwz34sOnSE
#        Transcript entries: 168
#        Chunks created:     13
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate _lwz34sOnSE
# [INFO] Processed video_id: BNF1wjBwTQA
#        Transcript entries: 180
#        Chunks created:     15
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate BNF1wjBwTQA
# [INFO] Processed video_id: fzdzPLlvs40
#        Transcript entries: 473
#        Chunks created:     35
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate fzdzPLlvs40
# [INFO] Processed video_id: _u2YaGT6RN0
#        Transcript entries: 243
#        Chunks created:     18
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate _u2YaGT6RN0
# [INFO] Processed video_id: mz1707QVxiY
#        Transcript entries: 325
#        Chunks created:     25
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate mz1707QVxiY
# [INFO] Processed video_id: L-mjQFN5aR0
#        Transcript entries: 398
#        Chunks created:     30
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate L-mjQFN5aR0
# [INFO] Processed video_id: 7KFE2ltnBAg
#        Transcript entries: 1
#        Chunks created:     0
#   ⚠️  Warning: No chunks generated for video_id 7KFE2ltnBAg
# [INFO] Processed video_id: hae_jXe2fN0
#        Transcript entries: 323
#        Chunks created:     24
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate hae_jXe2fN0
# [INFO] Processed video_id: OUrlxnUAAEA
#        Transcript entries: 1
#        Chunks created:     0
#   ⚠️  Warning: No chunks generated for video_id OUrlxnUAAEA
# [INFO] Processed video_id: Y-NGmnFpNuM
#        Transcript entries: 271
#        Chunks created:     20
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate Y-NGmnFpNuM
# [INFO] Processed video_id: Zz6oRGsJkW4
#        Transcript entries: 163
#        Chunks created:     12
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate Zz6oRGsJkW4
# [INFO] Processed video_id: gmg5jw1bM8A
#        Transcript entries: 97
#        Chunks created:     7
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate gmg5jw1bM8A
# [INFO] Processed video_id: FW_l7lB0HUI
#        Transcript entries: 1
#        Chunks created:     0
#   ⚠️  Warning: No chunks generated for video_id FW_l7lB0HUI
# [INFO] Processed video_id: Jt2dDLSlBng
#        Transcript entries: 491
#        Chunks created:     38
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate Jt2dDLSlBng
# [INFO] Processed video_id: gRLP_mlglMM
#        Transcript entries: 369
#        Chunks created:     29
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate gRLP_mlglMM
# [INFO] Processed video_id: dnBZLk53sQI
#        Transcript entries: 851
#        Chunks created:     68
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate dnBZLk53sQI
# [INFO] Processed video_id: B5PATo1J6yw
#        Transcript entries: 48
#        Chunks created:     4
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate B5PATo1J6yw
# [INFO] Processed video_id: hvIQPAwkVZo
#        Transcript entries: 381
#        Chunks created:     30
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate hvIQPAwkVZo
# [INFO] Processed video_id: BIIZaVtUbf4
#        Transcript entries: 409
#        Chunks created:     33
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate BIIZaVtUbf4
# [INFO] Processed video_id: -v8XEQ2AHvQ
#        Transcript entries: 166
#        Chunks created:     13
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate -v8XEQ2AHvQ
# [INFO] Processed video_id: agIFak9A3m8
#        Transcript entries: 114
#        Chunks created:     9
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate agIFak9A3m8
# [INFO] Processed video_id: EJpqZ7OlwFU
#        Transcript entries: 396
#        Chunks created:     30
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate EJpqZ7OlwFU
# [INFO] Processed video_id: W7ubna1Rfv8
#        Transcript entries: 167
#        Chunks created:     13
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate W7ubna1Rfv8
# [INFO] Processed video_id: Q7ZWPgPnRz8
#        Transcript entries: 1
#        Chunks created:     0
#   ⚠️  Warning: No chunks generated for video_id Q7ZWPgPnRz8
# [INFO] Processed video_id: BMXh8JGROHM
#        Transcript entries: 410
#        Chunks created:     31
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate BMXh8JGROHM
# [INFO] Processed video_id: wAtyYZ6zvAs
#        Transcript entries: 491
#        Chunks created:     37
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate wAtyYZ6zvAs
# [INFO] Processed video_id: HGPJ4ekhcLg
#        Transcript entries: 413
#        Chunks created:     32
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate HGPJ4ekhcLg
# [INFO] Processed video_id: sSAqYSk7Br4
#        Transcript entries: 1
#        Chunks created:     0
#   ⚠️  Warning: No chunks generated for video_id sSAqYSk7Br4
# [INFO] Processed video_id: GJGmlfZoCoU
#        Transcript entries: 167
#        Chunks created:     13
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate GJGmlfZoCoU
# [INFO] Processed video_id: tfuQdI3YO2c
#        Transcript entries: 293
#        Chunks created:     23
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate tfuQdI3YO2c
# [INFO] Processed video_id: YGiQvFbSIg8
#        Transcript entries: 407
#        Chunks created:     33
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate YGiQvFbSIg8
# [INFO] Processed video_id: XODz6LwKY7g
#        Transcript entries: 701
#        Chunks created:     56
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate XODz6LwKY7g
# [INFO] Processed video_id: XJaxwH50Qok
#        Transcript entries: 358
#        Chunks created:     27
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate XJaxwH50Qok
# [INFO] Processed video_id: FZhcmOfNNZE
#        Transcript entries: 621
#        Chunks created:     50
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate FZhcmOfNNZE
# [INFO] Processed video_id: xFarGClszEM
#        Transcript entries: 471
#        Chunks created:     37
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate xFarGClszEM
# [INFO] Processed video_id: VX6ftRzYROM
#        Transcript entries: 437
#        Chunks created:     36
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate VX6ftRzYROM
# [INFO] Processed video_id: lqdnyIVQq-M
#        Transcript entries: 181
#        Chunks created:     15
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate lqdnyIVQq-M
# [INFO] Processed video_id: JZ6sRZ_5j_c
#        Transcript entries: 111
#        Chunks created:     9
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate JZ6sRZ_5j_c
# [INFO] Processed video_id: it1Lu7NmMpw
#        Transcript entries: 179
#        Chunks created:     14
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate it1Lu7NmMpw
# [INFO] Processed video_id: R6o_CUmoN9Q
#        Transcript entries: 231
#        Chunks created:     20
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate R6o_CUmoN9Q
# [INFO] Processed video_id: qGDXEz-cr6M
#        Transcript entries: 1
#        Chunks created:     0
#   ⚠️  Warning: No chunks generated for video_id qGDXEz-cr6M
# [INFO] Processed video_id: BN-fnYzbdc8
#        Transcript entries: 564
#        Chunks created:     48
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate BN-fnYzbdc8
# [INFO] Processed video_id: WKHylqfNmq4
#        Transcript entries: 842
#        Chunks created:     68
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate WKHylqfNmq4
# [INFO] Processed video_id: 2gPmRRGz0Hc
#        Transcript entries: 246
#        Chunks created:     20
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 2gPmRRGz0Hc
# [INFO] Processed video_id: NRpGUx0o3Ps
#        Transcript entries: 236
#        Chunks created:     20
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate NRpGUx0o3Ps
# [INFO] Processed video_id: bSRRrorvAZs
#        Transcript entries: 287
#        Chunks created:     23
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate bSRRrorvAZs
# [INFO] Processed video_id: 74YmhVM6FTM
#        Transcript entries: 381
#        Chunks created:     32
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 74YmhVM6FTM
# [INFO] Processed video_id: aoPfVsS3BDE
#        Transcript entries: 672
#        Chunks created:     52
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate aoPfVsS3BDE
# [INFO] Processed video_id: _QpDGJwFjYA
#        Transcript entries: 169
#        Chunks created:     15
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate _QpDGJwFjYA
# [INFO] Processed video_id: cM1WHKae1wo
#        Transcript entries: 192
#        Chunks created:     15
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate cM1WHKae1wo
# [INFO] Processed video_id: mn0BcXJlRFM
#        Transcript entries: 172
#        Chunks created:     12
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate mn0BcXJlRFM
# [INFO] Processed video_id: JLIVwIsU6RA
#        Transcript entries: 81
#        Chunks created:     6
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate JLIVwIsU6RA
# [INFO] Processed video_id: _UX8-2WhHZo
#        Transcript entries: 1
#        Chunks created:     0
#   ⚠️  Warning: No chunks generated for video_id _UX8-2WhHZo
# [INFO] Processed video_id: OzZA4mSBE0Q
#        Transcript entries: 586
#        Chunks created:     46
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate OzZA4mSBE0Q
# [INFO] Processed video_id: XXBUivsHhec
#        Transcript entries: 1
#        Chunks created:     0
#   ⚠️  Warning: No chunks generated for video_id XXBUivsHhec
# [INFO] Processed video_id: y4_YQjfOsDo
#        Transcript entries: 227
#        Chunks created:     18
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate y4_YQjfOsDo
# [INFO] Processed video_id: kBch5oD5BkY
#        Transcript entries: 347
#        Chunks created:     27
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate kBch5oD5BkY
# [INFO] Processed video_id: wyZ9aqQOXvs
#        Transcript entries: 122
#        Chunks created:     10
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate wyZ9aqQOXvs
# [INFO] Processed video_id: bu3nPiHCNLU
#        Transcript entries: 101
#        Chunks created:     8
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate bu3nPiHCNLU
# [INFO] Processed video_id: 7gI1UH31xb4
#        Transcript entries: 322
#        Chunks created:     27
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 7gI1UH31xb4
# [INFO] Processed video_id: 4SXZfzNZ3IQ
#        Transcript entries: 688
#        Chunks created:     65
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 4SXZfzNZ3IQ
# [INFO] Processed video_id: mvPER7YfTkw
#        Transcript entries: 185
#        Chunks created:     14
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate mvPER7YfTkw
# [INFO] Processed video_id: deXR2fThYDw
#        Transcript entries: 1
#        Chunks created:     0
#   ⚠️  Warning: No chunks generated for video_id deXR2fThYDw
# [INFO] Processed video_id: OIlrS14Zi0o
#        Transcript entries: 286
#        Chunks created:     23
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate OIlrS14Zi0o
# [INFO] Processed video_id: ZhQQfpWfkKY
#        Transcript entries: 588
#        Chunks created:     47
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate ZhQQfpWfkKY
# [INFO] Processed video_id: UjVkpszDzgk
#        Transcript entries: 249
#        Chunks created:     20
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate UjVkpszDzgk
# [INFO] Processed video_id: PPUCVRIV9t8
#        Transcript entries: 731
#        Chunks created:     59
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate PPUCVRIV9t8
# [INFO] Processed video_id: 6vHLMdnjO2w
#        Transcript entries: 607
#        Chunks created:     48
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 6vHLMdnjO2w
# [INFO] Processed video_id: 89jxeddZtC0
#        Transcript entries: 437
#        Chunks created:     36
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 89jxeddZtC0
# [INFO] Processed video_id: J5LMRTIu4jY
#        Transcript entries: 224
#        Chunks created:     17
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate J5LMRTIu4jY
# [INFO] Processed video_id: CFWK05dQoGM
#        Transcript entries: 247
#        Chunks created:     19
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate CFWK05dQoGM
# [INFO] Processed video_id: A3tFt14iTEI
#        Transcript entries: 563
#        Chunks created:     44
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate A3tFt14iTEI
# [INFO] Processed video_id: 8kBIDggLwgE
#        Transcript entries: 513
#        Chunks created:     38
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate 8kBIDggLwgE
# [INFO] Processed video_id: REGNWrHZiCw
#        Transcript entries: 357
#        Chunks created:     30
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate REGNWrHZiCw
# [INFO] Processed video_id: iXwQb2LRKGI
#        Transcript entries: 370
#        Chunks created:     29
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate iXwQb2LRKGI
# [INFO] Processed video_id: haowRqeAqJU
#        Transcript entries: 813
#        Chunks created:     65
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate haowRqeAqJU
# [INFO] Processed video_id: MpuTzBSYBBI
#        Transcript entries: 673
#        Chunks created:     53
#   ⚠️  Warning: Chunk count much lower than transcript entries. Investigate MpuTzBSYBBI
#
# ✅ Summary table saved to 'transcript_chunk_summary.csv'

# %%
#comparison
video_id = "GH3lrOsU3AU"
original_transcript = [entry for entry in transcript if entry["video_id"] == video_id]

chunked_transcript = [chunk for chunk in chunks if chunk["video_id"] == video_id]

# %%
print("🟡 ORIGINAL TRANSCRIPT:")
print(" ".join([entry["text"] for entry in original_transcript])[:500])

print("\n🟢 CHUNKED TRANSCRIPT:")
for i, chunk in enumerate(chunked_transcript[:3]):  # limit to first 3 chunks
    print(f"\n--- Chunk {i+1} ---")
    print(f"Start: {chunk['start_time']}s | End: {chunk['end_time']}s")
    print(chunk["text"][:500])
# Out:
# 🟡 ORIGINAL TRANSCRIPT:
# Hi everyone, welcome to our bonus module of LLM Zoom camp. In this bonus module, we are going to talk about agents. When we launched our course this year a couple of uh weeks ago, I think it was one month one month one month ago, everyone everyone was asking like every second person in the Q&A section section was asking, "Hey, but what about agents? What about agents?" And uh the answer I gave back then was that agents are still actively evolving. Uh so it doesn't make sense to invest a lot of t
#
# 🟢 CHUNKED TRANSCRIPT:
#
# --- Chunk 1 ---
# Start: 0.0s | End: 34.719s
# Hi everyone, welcome to our bonus module of LLM Zoom camp. In this bonus module, we are going to talk about agents. When we launched our course this year a couple of uh weeks ago, I think it was one month one month one month ago, everyone everyone was asking like every second person in the Q&A section section was asking, "Hey, but what about agents? What about agents?" And uh the answer I gave back then was
#
# --- Chunk 2 ---
# Start: 30.48s | End: 66.799s
# that agents are still actively evolving. Uh so it doesn't make sense to invest a lot of time into creating content which will become obsolete in one year. uh but I already had some materials and I thought how about making this module lightweight so I don't put too much effort but at the same time share with you what I already know what the content I already have and we do it not by creating a module like we typically do uh but we do a it live like workshop
#
# --- Chunk 3 ---
# Start: 63.6s | End: 97.2s
# style life uh workshop kind of live right so we will have this module for me it's a little lower effort to record this. So next year we are probably going to re-record it anyways and for you I hope it will be quite useful. So the content for this uh workshop/module is already in zero a agents. So um we're here now we just finished week two uh module two sorry and we are starting

# %%
#Check missing values
original_words = set(" ".join([entry["text"] for entry in original_transcript]).split())
chunked_words = set(" ".join([chunk["text"] for chunk in chunked_transcript]).split())

missing_words = original_words - chunked_words
print(f"❌ Missing words in chunks: {missing_words}")
# Out:
# ❌ Missing words in chunks: set()

# %%
s = 97.2  # set your desired timestamp cutoff
video_id = "GH3lrOsU3AU"

# Filter transcript entries up to timestamp `s` for the specific video
for entry in transcript:
    if entry["video_id"] == video_id and entry["start"] <= s:
        print(f"{entry['start']:.2f}s - {entry['text']}")

transcript_until_s = [
    entry for entry in transcript
    if entry["video_id"] == video_id and entry["start"] <= s
]
# Out:
# 0.00s - Hi everyone, welcome to our bonus module
# 2.88s - of LLM Zoom camp. In this bonus module,
# 5.84s - we are going to talk about agents. When
# 8.32s - we launched our course this year a
# 11.20s - couple of uh weeks ago, I think it was
# 13.60s - one month one month one month ago,
# 16.96s - everyone everyone was asking like every
# 20.08s - second person in the Q&A section section
# 23.20s - was asking, "Hey, but what about agents?
# 24.96s - What about agents?"
# 26.96s - And uh the answer I gave back then was
# 30.48s - that agents are still actively evolving.
# 34.72s - Uh so it doesn't make sense to invest a
# 36.96s - lot of time into creating content which
# 39.36s - will become obsolete in one year.
# 42.40s - uh but I already had some materials and
# 44.64s - I thought how about making this module
# 46.72s - lightweight so I don't put too much
# 49.36s - effort but at the same time share with
# 51.60s - you what I already know what the content
# 53.68s - I already have and we do it not by
# 57.12s - creating a module like we typically do
# 59.84s - uh but we do a it live like workshop
# 63.60s - style life uh workshop kind of live
# 66.80s - right so we will have this module for me
# 70.24s - it's a little lower effort to record
# 72.88s - this. So next year we are probably going
# 75.28s - to re-record it anyways and for you I
# 78.96s - hope it will be quite useful. So the
# 81.44s - content for this uh workshop/module
# 85.20s - is already in zero a agents. So um we're
# 89.76s - here now we just finished week two uh
# 93.12s - module two sorry and we are starting
# 94.80s - module 3. We still need to finish a few
# 97.20s - things for this module module modules

# %%
#compare videos seaconds orig versus new
video_id = "GH3lrOsU3AU"
cutoff_time = 97.2

transcript_entries_until_s = [
    entry for entry in transcript
    if entry["video_id"] == video_id and entry["start"] <= cutoff_time
]
print(f"Transcript entries up to {cutoff_time}s: {len(transcript_entries_until_s)}")
# Out:
# Transcript entries up to 97.2s: 35

# %%
#compare videos seaconds orig versus new
chunks_until_s = [
    chunk for chunk in chunks
    if chunk["video_id"] == video_id and chunk["start_time"] <= cutoff_time
]
print(f"Chunks up to {cutoff_time}s: {len(chunks_until_s)}")
# Out:
# Chunks up to 97.2s: 4

# %%
#compare videos seaconds orig versus new
video_id = "GH3lrOsU3AU"
cutoff_time = 97.2

transcript_entries_until_s = [
    entry for entry in transcript
    if entry["video_id"] == video_id 
]
print(f"Transcript entries for {video_id} up to {cutoff_time}s: {len(transcript_entries_until_s)}")
# Out:
# Transcript entries for GH3lrOsU3AU up to 97.2s: 2012

# %%
chunks_until_s = [
    chunk for chunk in chunks
    if chunk["video_id"] == video_id 
]
print(f"Chunks  for {video_id} up to {cutoff_time}s: {len(chunks_until_s)}")
# Out:
# Chunks  for GH3lrOsU3AU up to 97.2s: 179

# %%
# Code: Compare Transcript vs Chunks per Video ID

import pandas as pd

# Step 1: Get all video_ids present in transcripts and chunks
video_ids = set([entry["video_id"] for entry in transcript]) | set([chunk["video_id"] for chunk in chunks])

# Step 2: Count entries for each video_id
rows = []
for video_id in video_ids:
    transcript_count = sum(1 for entry in transcript if entry["video_id"] == video_id)
    chunk_count = sum(1 for chunk in chunks if chunk["video_id"] == video_id)
    rows.append({
        "video_id": video_id,
        "transcript_entries": transcript_count,
        "chunk_entries": chunk_count
    })

# Step 3: Create DataFrame
df = pd.DataFrame(rows)

# Step 4: Display the result
print(df)
# Out:
#         video_id  transcript_entries  chunk_entries
# 0    82TYlOvKwfk                 522              0
# 1    Zz6oRGsJkW4                 163              0
# 2    ZdbIk8AltDU                 590              0
# 3    hCAIVe9N0ow                 265              0
# 4    HIm2BOj8C0Q                 187              0
# ..           ...                 ...            ...
# 510  XODz6LwKY7g                 701              0
# 511  OzZA4mSBE0Q                 586              0
# 512  W3Zm6rjOq70                 148              0
# 513  gsKuETFJr54                 155              0
# 514  _lwz34sOnSE                 168              0
#
# [515 rows x 3 columns]

# %%
video_id='82TYlOvKwfk'
chunked_transcript = [chunk for chunk in chunks if chunk["video_id"] == video_id]
len(chunked_transcript)
# Out:
# 0

# %%
video_id='82TYlOvKwfk'
chunked_transcript = [entry for entry in transcript
    if entry["video_id"] == video_id == video_id]
len(chunked_transcript)
# Out:
# 522

# %%
all_zoomcamp_metadata
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 all_zoomcamp_metadata
#
# NameError: name 'all_zoomcamp_metadata' is not defined

# %%
from youtube_transcript_api import YouTubeTranscriptApi


# Extract the video ID from the URL
video_url = "https://www.youtube.com/watch?v=2jM7t-NTZxs"
video_id = video_url.split("v=")[-1]

# Fetch transcript
trans=YouTubeTranscriptApi()
transcript = trans.fetch(video_id)

# Print lines
for entry in transcript:
    print(f"[{entry['start']:.2f}s] {entry['text']}")
# Out:
# ---------------------------------------------------------------------------
# RequestBlocked                            Traceback (most recent call last)
# Cell In[5], line 10
#       8 # Fetch transcript
#       9 trans=YouTubeTranscriptApi()
# ---> 10 transcript = trans.fetch(video_id)
#      12 # Print lines
#      13 for entry in transcript:
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/youtube_transcript_api/_api.py:71, in YouTubeTranscriptApi.fetch(self, video_id, languages, preserve_formatting)
#      51 def fetch(
#      52     self,
#      53     video_id: str,
#      54     languages: Iterable[str] = ("en",),
#      55     preserve_formatting: bool = False,
#      56 ) -> FetchedTranscript:
#      57     """
#      58     Retrieves the transcript for a single video. This is just a shortcut for
#      59     calling:
#    (...)     68     :param preserve_formatting: whether to keep select HTML text formatting
#      69     """
#      70     return (
# ---> 71         self.list(video_id)
#      72         .find_transcript(languages)
#      73         .fetch(preserve_formatting=preserve_formatting)
#      74     )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/youtube_transcript_api/_api.py:127, in YouTubeTranscriptApi.list(self, video_id)
#      76 def list(
#      77     self,
#      78     video_id: str,
#      79 ) -> TranscriptList:
#      80     """
#      81     Retrieves the list of transcripts which are available for a given video. It
#      82     returns a `TranscriptList` object which is iterable and provides methods to
#    (...)    125         Make sure that this is the actual ID, NOT the full URL to the video!
#     126     """
# --> 127     return self._fetcher.fetch(video_id)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/youtube_transcript_api/_transcripts.py:356, in TranscriptListFetcher.fetch(self, video_id)
#     352 def fetch(self, video_id: str) -> TranscriptList:
#     353     return TranscriptList.build(
#     354         self._http_client,
#     355         video_id,
# --> 356         self._fetch_captions_json(video_id),
#     357     )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/youtube_transcript_api/_transcripts.py:373, in TranscriptListFetcher._fetch_captions_json(self, video_id, try_number)
#     371 if try_number + 1 < retries:
#     372     return self._fetch_captions_json(video_id, try_number=try_number + 1)
# --> 373 raise exception.with_proxy_config(self._proxy_config)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/youtube_transcript_api/_transcripts.py:364, in TranscriptListFetcher._fetch_captions_json(self, video_id, try_number)
#     362     api_key = self._extract_innertube_api_key(html, video_id)
#     363     innertube_data = self._fetch_innertube_data(video_id, api_key)
# --> 364     return self._extract_captions_json(innertube_data, video_id)
#     365 except RequestBlocked as exception:
#     366     retries = (
#     367         0
#     368         if self._proxy_config is None
#     369         else self._proxy_config.retries_when_blocked
#     370     )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/youtube_transcript_api/_transcripts.py:385, in TranscriptListFetcher._extract_captions_json(self, innertube_data, video_id)
#     384 def _extract_captions_json(self, innertube_data: Dict, video_id: str) -> Dict:
# --> 385     self._assert_playability(innertube_data.get("playabilityStatus"), video_id)
#     387     captions_json = innertube_data.get("captions", {}).get(
#     388         "playerCaptionsTracklistRenderer"
#     389     )
#     390     if captions_json is None or "captionTracks" not in captions_json:
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/youtube_transcript_api/_transcripts.py:404, in TranscriptListFetcher._assert_playability(self, playability_status_data, video_id)
#     402 if playability_status == _PlayabilityStatus.LOGIN_REQUIRED.value:
#     403     if reason == _PlayabilityFailedReason.BOT_DETECTED.value:
# --> 404         raise RequestBlocked(video_id)
#     405     if reason == _PlayabilityFailedReason.AGE_RESTRICTED.value:
#     406         raise AgeRestricted(video_id)
#
# RequestBlocked:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=2jM7t-NTZxs! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# There are two things you can do to work around this:
# 1. Use proxies to hide your IP address, as explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
# 2. (NOT RECOMMENDED) If you authenticate your requests using cookies, you will be able to continue doing requests for a while. However, YouTube will eventually permanently ban the account that you have used to authenticate with! So only do this if you don't mind your account being banned!
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!

# %%
# import google.genai as genai # For using Youtube tool
from google import genai
client = genai.Client(api_key=GEMINI_API_KEY)
# client = genai.Client(api_key=GOOGLE_API_KEY)
# model = genai.GenerativeModel("gemini-pro")
response = client.models.generate_content(
    model="gemini-2.0-flash",
    contents="Explain AI to me like I'm a kid.")

print(response.text)
# Out:
# Imagine you have a really smart puppy, but it doesn't know anything yet. You have to teach it tricks.
#
# **AI is like that smart puppy.** It's a computer program that we try to teach to do things that usually need a human brain, like:
#
# *   **Recognizing pictures:** Like teaching your puppy to know which picture is a dog and which is a cat.
# *   **Understanding words:** Like teaching your puppy to understand "sit" or "fetch."
# *   **Playing games:** Like teaching your puppy to play hide-and-seek, but with computers playing instead of puppies!
# *   **Solving problems:** Like giving your puppy a puzzle to figure out how to get a treat.
#
# **How do we teach the AI puppy?**
#
# We give it lots and lots of examples! Like if we want it to recognize dogs, we show it thousands of pictures of dogs. The AI looks for patterns in those pictures to learn what makes a dog a dog.
#
# **So, AI is like a super-smart program that learns from examples, just like you learn at school, but way faster!**
#
# **Think of it like this:**
#
# *   You learn to ride a bike by falling down a few times and figuring out how to balance.
# *   AI learns to drive a car by driving in a simulator millions of times, learning from its mistakes.
#
# AI can't really "think" like you do, or have feelings. It just does what it's programmed to do, based on what it has learned.
#
# AI is used in lots of things we use every day, like:
#
# *   When you ask Siri or Alexa a question.
# *   When you watch a movie on Netflix and it suggests other movies you might like.
# *   When you use a GPS to find directions.
#
# **So, AI is like a really cool tool that can help us do all sorts of amazing things!**
